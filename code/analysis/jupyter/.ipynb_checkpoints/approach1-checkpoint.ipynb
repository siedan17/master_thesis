# %% [markdown]
# # APPROACH 1

# %% [markdown]
# ## Import & Globals:

# %%
import sys
import os
import random as rd

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedShuffleSplit
# from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

import tensorflow as tf
from tensorflow import keras


raw_data_folder = os.path.abspath('/home/siedan/programming/masterarbeit/code/analysis/raw_data')

def load_df(name):
    return pd.read_csv(os.path.join(raw_data_folder, name))

df = load_df('adapted_data.csv').drop(['Unnamed: 0'], axis =1)

features_year1 = ['styria_dummy', 'not_styria_dummy', 'germany_dummy', 'other_foreign_dummy',
                  'num_parallel_studies', 'cum_ects_pos_before', 'years_since_matura', 'firstGen',
                  'geschlecht', 'AHS_dummy', 'BHS_dummy', 'ausland_vorbildung_dummy', 'sonstige_vorbildung_dummy',
                  'delayed_dummy', 'ECTS_year', 'active_dummy']

features_years = ['styria_dummy', 'not_styria_dummy', 'germany_dummy', 'other_foreign_dummy',
                  'num_parallel_studies', 'cum_ects_pos_before', 'avgECTS_sem_before', 'ects_year_before',
                  'full_duration_sem_before', 'geschlecht', 'years_since_matura', 'firstGen', 'AHS_dummy',
                  'BHS_dummy', 'ausland_vorbildung_dummy', 'sonstige_vorbildung_dummy', 'delayed_dummy',
                  'ECTS_year', 'active_dummy']

scaler = StandardScaler()

# %% [markdown]
# ## Algorithms for transition:

# %% [markdown]
# ### Help Functions:

# %%
def active(df_, prediction):
    df = df_.copy(deep = True)
    df.reset_index(drop = True)
    if len(df) == len(prediction):
        new_column = []
        for i in range(len(prediction)):
            if prediction[i] >= 16:
#             a = rd.random()
#             if a > 0.1:
                new_column.append(1)
            else:
                new_column.append(0)
        df.insert(len(df.columns), 'active_predicted', new_column, allow_duplicates = True)
        df.insert(len(df.columns), 'ECTS_predicted', prediction, allow_duplicates = True)
    else:
        print('ERROR')
    return df
        
    
def ratio(df):
    ratio = 0
    for i in df.index:
        if df.loc[i, 'active_dummy'] == df.loc[i, 'active_predicted']:
            ratio +=1
    ratio = ratio/len(df)
    return ratio


def display_scores(scores):
    print('Scores: ', scores)
    print('Mean: ', scores.mean())
    print('Standard deviation: ', scores.std())


def create_data(Studienjahr, df, features):
    df = df.query('Studienjahr == @Studienjahr')[features].dropna().reset_index(drop = True).copy(deep = True)
    split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.1, random_state = 42)
    for train_index, test_index in split.split(df, df['active_dummy']):
        df_train = df.loc[train_index, :]
        df_test = df.loc[test_index, :]
    df_train_copy = df_train.copy(deep = True)
    y_train = list(df_train['ECTS_year'])
    y_test = list(df_test['ECTS_year'])
    df_train = scaler.fit_transform(df_train.drop(['ECTS_year', 'active_dummy'], axis = 1))
    df_test = scaler.fit_transform(df_test.drop(['ECTS_year', 'active_dummy'], axis = 1))
    return df_train, y_train, df_test, y_test, df_train_copy


def training_regression(df_train, y_train, df_train_copy, model): # df_train is already scaled!
    model = sklearn.base.clone(model)
    model.fit(df_train, y_train)
    
    predictions = model.predict(df_train)
    rmse = np.sqrt(mean_squared_error(y_train, predictions))
    mae = mean_absolute_error(y_train, predictions)
    R_squared = r2_score(y_train, predictions)
    
    print('RMSE = ' + str(rmse))
    print('MAE = ' + str(mae))
    print('R2_score = ' + str(R_squared))
    print('----------')
    df_new = active(df_train_copy, predictions)
    print('Ratio = ' + str(ratio(df_new)))
    scores = cross_val_score(model, df_train, y_train, scoring = 'neg_mean_squared_error', cv = 5)
    rmse_scores = np.sqrt(-scores)
    display_scores(rmse_scores)
    print('##########')
    
    return model

# %% [markdown]
# ### Data Generating:

# %%
# Year 1 - 2:
df1_train, y1_train, df1_test, y1_test, df1_train_copy = create_data(1, df, features_year1)

#  Year 2 - 3:
df2_train, y2_train, df2_test, y2_test, df2_train_copy = create_data(2, df, features_years)  

# Year 3 - 4:
df3_train, y3_train, df3_test, y3_test, df3_train_copy = create_data(3, df, features_years)
    
# Year 4 ~:
df4_train, y4_train, df4_test, y4_test, df4_train_copy = create_data(4, df, features_years)

# %% [markdown]
# ### Linear Regression:

# %%
lin_reg = LinearRegression()

# Year 1 - 2:

reg1 = training_regression(df1_train, y1_train, df1_train_copy, lin_reg)

# Year 2 - 3:

reg2 = training_regression(df2_train, y2_train, df2_train_copy, lin_reg)

# Year 3 - 4:

reg3 = training_regression(df3_train, y3_train, df3_train_copy, lin_reg)

# Year 4~ :

reg4 = training_regression(df4_train, y4_train, df4_train_copy, lin_reg)
# Out:
# RMSE = 18.770113085877604
# MAE = 15.558727895718143
# R2_score = 0.06148752670614199
# ----------
# Ratio = 0.6194099378881988
# Scores:  [18.48978664 18.80458555 18.86944927 19.2046935  18.71250997]
# Mean:  18.816204985510645
# Standard deviation:  0.23289263011469744
# ##########
# RMSE = 16.857002608696565
# MAE = 13.428229342564679
# R2_score = 0.43002609465224206
# ----------
# Ratio = 0.7659945232760766
# Scores:  [16.86994312 17.20695515 17.45038643 16.50014502 16.64268332]
# Mean:  16.934022606711324
# Standard deviation:  0.35166981670040687
# ##########
# RMSE = 16.595761224073737
# MAE = 13.198127481052236
# R2_score = 0.4325957971068436
# ----------
# Ratio = 0.8502738892270237
# Scores:  [16.48071184 17.06395348 16.35750781 16.6121237  16.93762195]
# Mean:  16.690383757122095
# Standard deviation:  0.26891426606308894
# ##########
# RMSE = 16.475581674656155
# MAE = 13.176933713166498
# R2_score = 0.3637641814465943
# ----------
# Ratio = 0.8521323236349143
# Scores:  [17.11038302 16.18871138 16.19059064 16.68303555 16.83383454]
# Mean:  16.601311024006996
# Standard deviation:  0.36299588921634596
# ##########

# %% [markdown]
# ### Support Vector Machines:

# %% [markdown]
# ### Hyperparameters:
# - kernel: linear, polynomial, gaussian or sigmoid. Uses the kernel trick to compute additional features.
#
# - gamma: if the model ist underfitting I should increase it. If the model is overfitting I should decrease it.
#
# - C: is a parameter which controls the margin violations. Higher more violations, but generalizes better.
#
# - epsilion (only for regression): controls the width of the "street". Similar to C. However, I don't get the difference.

# %%
svm_reg = SVR(kernel = 'rbf', gamma = 10, C = 100, epsilon = 5)

# Year 1 - 2:
svm1 = training_regression(df1_train, y1_train, df1_train_copy, svm_reg)

# Year 2 - 3:
svm2 = training_regression(df2_train, y2_train, df2_train_copy, svm_reg)

# Year 3 - 4:
svm3 = training_regression(df3_train, y3_train, df3_train_copy, svm_reg)

# Year 4 ~ :
svm4 = training_regression(df4_train, y4_train, df4_train_copy, svm_reg)

# df4_new[['active_dummy', 'active_pred', 'ECTS_year', 'ECTS_pred']][150:165]
# Out:
# RMSE = 17.81359634096341
# MAE = 13.753595455763294
# R2_score = 0.15470269474905918
# ----------
# Ratio = 0.6720496894409937
# Scores:  [18.98163716 19.72700352 19.74305725 20.35884122 19.33905982]
# Mean:  19.6299197937936
# Standard deviation:  0.46009166046596917
# ##########
# RMSE = 11.471683948938592
# MAE = 8.042499097101123
# R2_score = 0.7360336227901706
# ----------
# Ratio = 0.8964401294498382
# Scores:  [20.92051286 20.76743727 21.47364307 20.19589954 20.64150101]
# Mean:  20.799798747913854
# Standard deviation:  0.41459323856836977
# ##########
# RMSE = 7.546707647669227
# MAE = 5.756809416510013
# R2_score = 0.882668872151324
# ----------
# Ratio = 0.9485696895922093
# Scores:  [19.96596768 20.8024773  20.83295021 20.44175867 20.46122886]
# Mean:  20.500876543019437
# Standard deviation:  0.31382488511413026
# ##########
# RMSE = 6.4301695558874155
# MAE = 5.342068357909372
# R2_score = 0.9030871306438369
# ----------
# Ratio = 0.9103228377839777
# Scores:  [19.61086288 19.06437018 20.39364216 18.98021503 19.85364987]
# Mean:  19.580548023814394
# Standard deviation:  0.522200143644033
# ##########

# %% [markdown]
# ### Random Forest:

# %% [markdown]
# ### Hyperparameters:
# - n_estimators: number of Decsiontrees.
# - max_depths: maximal depth of each tree.
# - max_leaf_nodes: controls the depths of the trees.
# - criterion: mse or msa. function to measure the quality of the split.
# - max_samples: (bootstrap = True) How many samples from df_train are drawn to train each regressor.

# %%
forest_reg = RandomForestRegressor(
#             n_estimators = 500, max_depth = 150, max_leaf_nodes = 100, criterion = 'mae',
#             max_samples = 500
        )

forest1 = training_regression(df1_train, y1_train, df1_train_copy, forest_reg)

# Year 2 - 3:
forest2 = training_regression(df2_train, y2_train, df2_train_copy, forest_reg)

# Year 3 - 4:
forest3 = training_regression(df3_train, y3_train, df3_train_copy, forest_reg)

# Year 4 ~ :
forest4 = training_regression(df4_train, y4_train, df4_train_copy, forest_reg)

# df4_new[['active_dummy', 'active_pred', 'ECTS_year', 'ECTS_pred']][150:165]
# Out:
# RMSE = 17.429849723628767
# MAE = 14.05733039913918
# R2_score = 0.1907297858363749
# ----------
# Ratio = 0.6798136645962732
# Scores:  [18.78928751 19.36209913 19.47790635 19.71499577 19.25116334]
# Mean:  19.31909042004763
# Standard deviation:  0.30630654758304765
# ##########
# RMSE = 9.140212012722921
# MAE = 6.584120017740029
# R2_score = 0.8324259352310421
# ----------
# Ratio = 0.9128703012198158
# Scores:  [18.46154838 18.55691486 18.75483326 17.61013556 18.10076738]
# Mean:  18.296839887954995
# Standard deviation:  0.4036169141841462
# ##########
# RMSE = 6.164499774017275
# MAE = 4.6863652617163725
# R2_score = 0.9217122385585308
# ----------
# Ratio = 0.9440048691418138
# Scores:  [16.0170448  16.74097496 16.58808476 16.69161519 16.64826193]
# Mean:  16.53719632562591
# Standard deviation:  0.2648976140381581
# ##########
# RMSE = 6.131631433010295
# MAE = 4.6354346353128735
# R2_score = 0.9118771191851388
# ----------
# Ratio = 0.9143084894380231
# Scores:  [16.53591137 16.01989357 16.38652098 16.70904225 16.44496898]
# Mean:  16.419267430970606
# Standard deviation:  0.22751159908823565
# ##########

# %% [markdown]
# ### Artificial Neural Networks:

# %% [markdown]
# - epochs: So oft wird ueber alle Trainingsdaten iteriert.
# - batch_size: So gross ist ein batch fuer den ein Gradient berechnet wird. (Keine Ahnung wie das mit SGD geht)

# %%
def training_ann_regression(df_train, y_train, df_train_copy):
    model = keras.models.Sequential([
        keras.layers.Dense(60, activation = 'relu', input_shape = df_train.shape[1:]),
        keras.layers.Dense(40, activation = 'relu'),
        keras.layers.Dense(20, activation = 'relu'),
        keras.layers.Dense(1, activation = 'relu')
    ])
    model.compile(loss = 'huber', optimizer = 'sgd')
    history = model.fit(df_train, np.array(y_train), epochs = 35, validation_split = 0.1)
    
    predictions = model.predict(df_train)
    rmse = np.sqrt(mean_squared_error(y_train, predictions))
    mae = mean_absolute_error(y_train, predictions)
    R_squared = r2_score(y_train, predictions)
    
    print('RMSE = ' + str(rmse))
    print('MAE = ' + str(mae))
    print('R2_score = ' + str(R_squared))
    print('----------')
    df_new = active(df_train_copy, predictions)
    print('Ratio = ' + str(ratio(df_new)))
    print('##########')
    
    return model, history

# %%
ann1, history1 = training_ann_regression(df1_train, y1_train, df1_train_copy)

pd.DataFrame(history1.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0, 25)
plt.show()
# Out:
# Epoch 1/35
# 182/182 [==============================] - 1s 3ms/step - loss: 17.3166 - val_loss: 15.1522
# Epoch 2/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.5914 - val_loss: 14.9628
# Epoch 3/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.4909 - val_loss: 14.7947
# Epoch 4/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.4633 - val_loss: 14.7542
# Epoch 5/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.4182 - val_loss: 14.7207
# Epoch 6/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.3871 - val_loss: 14.7249
# Epoch 7/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.3654 - val_loss: 14.7210
# Epoch 8/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.3484 - val_loss: 14.6999
# Epoch 9/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.3502 - val_loss: 14.7731
# Epoch 10/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.3336 - val_loss: 14.8826
# Epoch 11/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.3266 - val_loss: 14.6146
# Epoch 12/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2968 - val_loss: 14.6618
# Epoch 13/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.3009 - val_loss: 14.6848
# Epoch 14/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2955 - val_loss: 14.8380
# Epoch 15/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2991 - val_loss: 14.6786
# Epoch 16/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2938 - val_loss: 14.6598
# Epoch 17/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2871 - val_loss: 14.6601
# Epoch 18/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2859 - val_loss: 14.7785
# Epoch 19/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2791 - val_loss: 14.7498
# Epoch 20/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2565 - val_loss: 14.8001
# Epoch 21/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2786 - val_loss: 14.6950
# Epoch 22/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2661 - val_loss: 14.6612
# Epoch 23/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2517 - val_loss: 14.6811
# Epoch 24/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2545 - val_loss: 14.7625
# Epoch 25/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2608 - val_loss: 14.9135
# Epoch 26/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2493 - val_loss: 14.6917
# Epoch 27/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2458 - val_loss: 14.7808
# Epoch 28/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2492 - val_loss: 14.7254
# Epoch 29/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2458 - val_loss: 14.7089
# Epoch 30/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2538 - val_loss: 14.6944
# Epoch 31/35
# 182/182 [==============================] - 0s 3ms/step - loss: 14.2184 - val_loss: 14.7456
# Epoch 32/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2475 - val_loss: 14.6453
# Epoch 33/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2329 - val_loss: 14.7849
# Epoch 34/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2300 - val_loss: 14.7477
# Epoch 35/35
# 182/182 [==============================] - 0s 2ms/step - loss: 14.2380 - val_loss: 14.7214
# RMSE = 19.249875664222845
# MAE = 14.697950284978988
# R2_score = 0.012897781187890645
# ----------
# Ratio = 0.6195652173913043
# ##########

# %%
ann2, history2 = training_ann_regression(df2_train, y2_train, df2_train_copy)

pd.DataFrame(history2.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0, 25)
plt.show()
# Out:
# Epoch 1/35
# 113/113 [==============================] - 1s 4ms/step - loss: 18.9804 - val_loss: 13.9863
# Epoch 2/35
# 113/113 [==============================] - 0s 3ms/step - loss: 13.1691 - val_loss: 13.5233
# Epoch 3/35
# 113/113 [==============================] - 0s 2ms/step - loss: 12.6821 - val_loss: 13.4430
# Epoch 4/35
# 113/113 [==============================] - 0s 2ms/step - loss: 12.5171 - val_loss: 13.1006
# Epoch 5/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.4389 - val_loss: 13.1580
# Epoch 6/35
# 113/113 [==============================] - 0s 2ms/step - loss: 12.3885 - val_loss: 13.1237
# Epoch 7/35
# 113/113 [==============================] - 0s 2ms/step - loss: 12.3500 - val_loss: 13.0193
# Epoch 8/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.2962 - val_loss: 13.3049
# Epoch 9/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.2451 - val_loss: 13.0543
# Epoch 10/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.2033 - val_loss: 13.0550
# Epoch 11/35
# 113/113 [==============================] - 0s 2ms/step - loss: 12.2065 - val_loss: 13.1809
# Epoch 12/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.2086 - val_loss: 13.0949
# Epoch 13/35
# 113/113 [==============================] - 0s 2ms/step - loss: 12.1206 - val_loss: 13.3809
# Epoch 14/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.1244 - val_loss: 13.2124
# Epoch 15/35
# 113/113 [==============================] - 0s 2ms/step - loss: 12.1134 - val_loss: 13.5084
# Epoch 16/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.0388 - val_loss: 13.0485
# Epoch 17/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.0730 - val_loss: 13.2308
# Epoch 18/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.0375 - val_loss: 13.1748
# Epoch 19/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.0280 - val_loss: 13.1377
# Epoch 20/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.0760 - val_loss: 13.1859
# Epoch 21/35
# 113/113 [==============================] - 0s 3ms/step - loss: 12.0168 - val_loss: 13.2255
# Epoch 22/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.9485 - val_loss: 13.2800
# Epoch 23/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.9606 - val_loss: 13.5117
# Epoch 24/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.9558 - val_loss: 13.1398
# Epoch 25/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.9623 - val_loss: 13.1784
# Epoch 26/35
# 113/113 [==============================] - 0s 2ms/step - loss: 11.9346 - val_loss: 13.2004
# Epoch 27/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.9431 - val_loss: 13.1950
# Epoch 28/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.8790 - val_loss: 13.1901
# Epoch 29/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.8846 - val_loss: 13.1381
# Epoch 30/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.8598 - val_loss: 13.1157
# Epoch 31/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.8615 - val_loss: 13.1065
# Epoch 32/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.8959 - val_loss: 13.1715
# Epoch 33/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.8326 - val_loss: 13.1822
# Epoch 34/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.8161 - val_loss: 13.6003
# Epoch 35/35
# 113/113 [==============================] - 0s 3ms/step - loss: 11.8216 - val_loss: 13.1565
# RMSE = 16.90261470224107
# MAE = 12.259380824854636
# R2_score = 0.42693742268532586
# ----------
# Ratio = 0.7861588249937764
# ##########

# %%
ann3, history3 = training_ann_regression(df3_train, y3_train, df3_train_copy)

pd.DataFrame(history3.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0, 25)
plt.show()
# Out:
# Epoch 1/35
# 93/93 [==============================] - 1s 4ms/step - loss: 24.7856 - val_loss: 15.1750
# Epoch 2/35
# 93/93 [==============================] - 0s 3ms/step - loss: 13.4069 - val_loss: 13.1625
# Epoch 3/35
# 93/93 [==============================] - 0s 2ms/step - loss: 12.3164 - val_loss: 12.5737
# Epoch 4/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.9842 - val_loss: 12.5980
# Epoch 5/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.8166 - val_loss: 12.1912
# Epoch 6/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.6961 - val_loss: 12.3009
# Epoch 7/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.6228 - val_loss: 12.2916
# Epoch 8/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.4915 - val_loss: 12.0318
# Epoch 9/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.4971 - val_loss: 12.2623
# Epoch 10/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.4502 - val_loss: 12.1728
# Epoch 11/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.4724 - val_loss: 11.9682
# Epoch 12/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.3495 - val_loss: 12.1610
# Epoch 13/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.3208 - val_loss: 12.4152
# Epoch 14/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.3556 - val_loss: 12.0139
# Epoch 15/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.2728 - val_loss: 11.8916
# Epoch 16/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.2556 - val_loss: 12.3238
# Epoch 17/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.2199 - val_loss: 11.9636
# Epoch 18/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.1935 - val_loss: 13.2103
# Epoch 19/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.1913 - val_loss: 11.8264
# Epoch 20/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.1759 - val_loss: 12.1284
# Epoch 21/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.1486 - val_loss: 11.7782
# Epoch 22/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.0242 - val_loss: 12.0577
# Epoch 23/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.0645 - val_loss: 11.9603
# Epoch 24/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.0767 - val_loss: 12.6820
# Epoch 25/35
# 93/93 [==============================] - 0s 3ms/step - loss: 11.0476 - val_loss: 11.9131
# Epoch 26/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.0569 - val_loss: 12.1617
# Epoch 27/35
# 93/93 [==============================] - 0s 3ms/step - loss: 10.9780 - val_loss: 12.7997
# Epoch 28/35
# 93/93 [==============================] - 0s 3ms/step - loss: 10.9485 - val_loss: 11.9976
# Epoch 29/35
# 93/93 [==============================] - 0s 2ms/step - loss: 11.0052 - val_loss: 12.1992
# Epoch 30/35
# 93/93 [==============================] - 0s 3ms/step - loss: 10.9216 - val_loss: 12.1955
# Epoch 31/35
# 93/93 [==============================] - 0s 3ms/step - loss: 10.8872 - val_loss: 12.4989
# Epoch 32/35
# 93/93 [==============================] - 0s 3ms/step - loss: 10.8770 - val_loss: 11.8632
# Epoch 33/35
# 93/93 [==============================] - 0s 3ms/step - loss: 10.9008 - val_loss: 11.9767
# Epoch 34/35
# 93/93 [==============================] - 0s 2ms/step - loss: 10.8545 - val_loss: 12.0790
# Epoch 35/35
# 93/93 [==============================] - 0s 3ms/step - loss: 10.8315 - val_loss: 12.1426
# RMSE = 16.126367840643127
# MAE = 11.612870529493543
# R2_score = 0.46423872851403947
# ----------
# Ratio = 0.8469263542300669
# ##########

# %% [markdown]
# ## Performing Grid Search for Best Regressor:

# %% [markdown]
# # Simulation of Model 1:

# %%
df_pretty = load_df('df_pretty.csv').drop(['Unnamed: 0'], axis =1)
# df_pretty # Programmierung funktioniert!

# %%
groups = df_pretty.groupby('matrikel_num')
list_of_students = [] # list von df's, wobei jedes df einen Studenten oder eine Studentin ueber mehrere Jahre hinweg beschreibt.

for i in df_pretty['matrikel_num'].drop_duplicates():
    list_of_students.append(groups.get_group(i))
    
# len(list_of_students)

# %%
predictors = [svm1, svm2, svm3, svm4]
features = [features_year1[:-2], features_years[:-2]]

test_student = list_of_students[257]


def update(input_series):
    series = input_series.copy(deep = True)
    series['ects_year_before'] = series['ects_predicted']
    series['cum_ects_pos_before'] += series['ects_predicted']
    if series['Studienjahr'] == 1:
        series['full_duration_sem_before'] = 2
    else:
        series['full_duration_sem_before'] += 2
    series['avgECTS_sem_before'] = series['cum_ects_pos_before']/series['full_duration_sem_before']
    series['Studienjahr'] += 1
    return series

def predict(input_student, predictors, features):
    student = input_student.copy(deep = True)
    if student['Studienjahr'] == 1:
        predictor = predictors[0]
        feature = features[0]
    elif student['Studienjahr'] == 2:
        predictor = predictors[1]
        feature = features[1]
    elif student['Studienjahr'] == 3:
        predictor = predictors[2]
        feature = features[1]
    else:
        predictor = predictors[3]
        feature = features[1]
    
    student['ects_predicted'] = float(predictor.predict(pd.DataFrame(student[feature]).T))
    if student['ects_predicted'] >= 16:
        student['active_predicted'] = 1
    else:
        student['active_predicted'] = 0
    return student


def model_student(df, predictors, features):
    n_years = len(df)
    student = df.iloc[0].fillna(0) # Series object # fillna kann Fehler erzeugen!
    list_of_years = [] # initialisiere Liste der Jahre. Erster Eintrag soll dann erstes Jahr mit predicteten ECTS sein.
    
    for i in range(n_years):
        new_student = predict(student, predictors, features).copy(deep = True)
        
        list_of_years.append(new_student)
        
        student = update(list_of_years[-1])
        
    new_df = list_of_years[0].to_frame().T
    
    for year in list_of_years[1:]:
        new_df = new_df.append(year.to_frame().T)
    
    return new_df.reset_index(drop = True)
   
    
test = model_student(test_student, predictors, features)
test_student = test_student.append(test)[['ects_year_before', 'ects_predicted', 'ECTS_year', 'SWS_year',
                           'active_predicted', 'active_dummy', 'avgECTS_sem_before', 'full_duration_sem_before',
                           'cum_ects_pos_before','subject']]
test_student
# Programmierung funktioniert!
# Out:
#      ects_year_before ects_predicted ECTS_year SWS_year active_predicted  \
# 1085              NaN            NaN      65.0     36.0              NaN
# 1086             65.0            NaN      55.0     24.0              NaN
# 1087             55.0            NaN      32.0     16.0              NaN
# 1088             32.0            NaN       3.0      2.0              NaN
# 0                   0      14.536509      65.0     36.0                0
# 1           14.536509      24.010054      65.0     36.0                1
# 2           24.010054      27.114964      65.0     36.0                1
# 3           27.114964      26.226235      65.0     36.0                1
#
#      active_dummy avgECTS_sem_before full_duration_sem_before  \
# 1085            1                0.0                      0.0
# 1086            1               32.5                      2.0
# 1087            1               30.0                      4.0
# 1088            1               30.4                      5.0
# 0               1                0.0                      0.0
# 1               1           7.268255                        2
# 2               1           9.636641                        4
# 3               1          10.943588                        6
#
#      cum_ects_pos_before    subject
# 1085                 0.0  Padagogik
# 1086                65.0  Padagogik
# 1087               120.0  Padagogik
# 1088               152.0  Padagogik
# 0                    0.0  Padagogik
# 1              14.536509  Padagogik
# 2              38.546563  Padagogik
# 3              65.661528  Padagogik

# %%
test_data = list_of_students[:500]
count = 0
for student in test_data:
    prediction = model_student(student, predictors, features)
    student = student.append(prediction).reset_index(drop = True)
    if student['active_dummy'][3] == student['active_predicted'][7]:
        
        count += 1
count
# Out:
# 356

# %% [markdown]
# Es funktioniert leider nicht, dass man rein nur mit predicteten ECTS über Jahre hinweg weitervorhersagt, ob ein
# Student oder eine Studentin in ca. 3 Jahren noch prüfungsaktiv ist oder nicht. Es hängt nämlich auch von Abschluss
# oder Abbruch ab. Weiters sind die Fehlerfortpflanzungen zu groß.

# %% [markdown]
# # Model 2:

# %% [markdown]
# ## Calculation:

# %% [markdown]
# #### Hier schaue ich welche Kombinationen Sinn machen untersucht zu werden.

# %%
df = load_df('adapted_data.csv').drop(['Unnamed: 0'], axis =1)


def produce_dfs(studienjahre, combination, df): # both are lists
    return_list = []
    first = combination[0]
    second = combination[1]
    third = combination[2]
    fourth = combination[3]
    fifth = combination[4]
    sixth = combination[5]
    for year in studienjahre:
        if year == 1:
            dummy = df.query('Studienjahr == @year and geschlecht == @first and AHS_dummy == @second and first_exam_negative == @third and delayed_dummy == @fourth and styria_dummy == @fifth and num_parallel_studies == @sixth')
            return_list.append(dummy)
        else:
            df1 = df.query('ects_year_before < 16')
            df2 = df.query('ects_year_before >= 16')
            dummy1 = df1.query('Studienjahr == @year and geschlecht == @first and AHS_dummy == @second and first_exam_negative == @third and delayed_dummy == @fourth and styria_dummy == @fifth and num_parallel_studies == @sixth')
            dummy2 = df2.query('Studienjahr == @year and geschlecht == @first and AHS_dummy == @second and first_exam_negative == @third and delayed_dummy == @fourth and styria_dummy == @fifth and num_parallel_studies == @sixth')
            return_list.append(dummy1)
            return_list.append(dummy2)
            
    return return_list



combs = []
for i in [0,1]:
    for j in [0,1]:
        for k in [0,1]:
            for m in [0,1]:
                for n in [0,1]:
                    for x in [0,1,2,3]:
                        combs.append([i,j,k,m,n,x])

                        
# for comb in combs:
#     a = produce_dfs([1,2,3,4,5], comb, df)
#     b = 0
#     for i in a:
#         b += len(i)
#     print('------')
#     print(b)
#     print(comb)

# %%
def prob_year(df): # returns a list with probabilities
    a = len(df.query("active_dummy == 1 and status_key == 'I'"))
    b = len(df.query("active_dummy == 0 and status_key == 'I'"))
    c = len(df.query("active_dummy == 1 and status_key != 'I'"))
    d = len(df.query("active_dummy == 0 and status_key != 'I'"))
    denominator = len(df)
    print(denominator)
    if denominator > 0:
        return [a/denominator, b/denominator, c/denominator, d/denominator]
    else:
        return "Zero"

# %%
# Splitting df in first part: (Maenner AHS Steiermark)
df = load_df('adapted_data.csv').drop(['Unnamed: 0'], axis =1)

studienjahre = [1,2,3,4,5]
combination = [1, 1, 0, 0, 1, 0]

dataframes = produce_dfs(studienjahre, combination, df)

for df in dataframes:
    print(prob_year(df))

# %%
# Splitting df in second part: (Frauen AHS Steiermark)
df = load_df('adapted_data.csv').drop(['Unnamed: 0'], axis =1)

studienjahre = [1,2,3,4,5]
combination = [0, 1, 0, 0, 1, 0]

dataframes = produce_dfs(studienjahre, combination, df)
for df in dataframes:
    print(prob_year(df))

# %%
# Splitting df in fourth part: (Frauen und not AHS)
df = load_df('adapted_data.csv').drop(['Unnamed: 0'], axis =1)

studienjahre = [1,2,3,4,5]
combination = [0, 0, 0, 0, 1, 0]

dataframes = produce_dfs(studienjahre, combination, df)
for df in dataframes:
    print(prob_year(df))

# %%
# Splitting df in third part: (Maenner und not AHS)
# df = load_df('adapted_data.csv').drop(['Unnamed: 0'], axis =1)

# studienjahre = [1,2,3,4,5]
# combination = [1, 0, 0, 0, 1, 0]

# dataframes = produce_dfs(studienjahre, combination, df)
# for df in dataframes:
#     print(prob_year(df))

# %%
# # Splitting df in fifth part: (Frauen, not AHS, not styria)
# df = load_df('adapted_data.csv').drop(['Unnamed: 0'], axis =1)

# studienjahre = [1,2,3,4,5]
# combination = [0, 0, 0, 0, 0, 0]

# dataframes = produce_dfs(studienjahre, combination, df)
# for df in dataframes:
#     print(prob_year(df))

# %%
# # Splitting df in sixth part: (Frauen, noAHS, )
# df = load_df('adapted_data.csv').drop(['Unnamed: 0'], axis =1)

# studienjahre = [1,2,3,4,5]
# combination = [0, 1, 0, 0, 0, 0]

# dataframes = produce_dfs(studienjahre, combination, df)
# for df in dataframes:
#     print(prob_year(df))

# %% [markdown]
# ## Simulation of Model 2:
